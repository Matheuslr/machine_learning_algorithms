# %%
import seaborn as sn
import matplotlib.pyplot as plt  
import pandas as pd  

from sklearn import linear_model
from sklearn.model_selection import train_test_split  
from sklearn.metrics import confusion_matrix

# %%
X_train = pd.read_csv('dataset/train/X_train.txt',header=None, delim_whitespace=True)
X_train
# Out:
#            0         1         2         3         4         5         6    \
# 0     0.288585 -0.020294 -0.132905 -0.995279 -0.983111 -0.913526 -0.995112
# 1     0.278419 -0.016411 -0.123520 -0.998245 -0.975300 -0.960322 -0.998807
# 2     0.279653 -0.019467 -0.113462 -0.995380 -0.967187 -0.978944 -0.996520
# 3     0.279174 -0.026201 -0.123283 -0.996091 -0.983403 -0.990675 -0.997099
# 4     0.276629 -0.016570 -0.115362 -0.998139 -0.980817 -0.990482 -0.998321
# 5     0.277199 -0.010098 -0.105137 -0.997335 -0.990487 -0.995420 -0.997627
# 6     0.279454 -0.019641 -0.110022 -0.996921 -0.967186 -0.983118 -0.997003
# 7     0.277432 -0.030488 -0.125360 -0.996559 -0.966728 -0.981585 -0.996485
# 8     0.277293 -0.021751 -0.120751 -0.997328 -0.961245 -0.983672 -0.997596
# 9     0.280586 -0.009960 -0.106065 -0.994803 -0.972758 -0.986244 -0.995405
# 10    0.276880 -0.012722 -0.103438 -0.994815 -0.973077 -0.985357 -0.995509
# ...

# %%
X_test = pd.read_csv('dataset/test/X_test.txt',header=None, delim_whitespace=True)
X_test
# Out:
#            0         1         2         3         4         5         6    \
# 0     0.257178 -0.023285 -0.014654 -0.938404 -0.920091 -0.667683 -0.952501
# 1     0.286027 -0.013163 -0.119083 -0.975415 -0.967458 -0.944958 -0.986799
# 2     0.275485 -0.026050 -0.118152 -0.993819 -0.969926 -0.962748 -0.994403
# 3     0.270298 -0.032614 -0.117520 -0.994743 -0.973268 -0.967091 -0.995274
# 4     0.274833 -0.027848 -0.129527 -0.993852 -0.967445 -0.978295 -0.994111
# 5     0.279220 -0.018620 -0.113902 -0.994455 -0.970417 -0.965316 -0.994585
# 6     0.279746 -0.018271 -0.104000 -0.995819 -0.976354 -0.977725 -0.995996
# 7     0.274601 -0.025035 -0.116831 -0.995594 -0.982069 -0.985262 -0.995341
# 8     0.272529 -0.020954 -0.114472 -0.996784 -0.975906 -0.986597 -0.997029
# 9     0.275746 -0.010372 -0.099776 -0.998373 -0.986933 -0.991022 -0.998663
# 10    0.278596 -0.015232 -0.098908 -0.998785 -0.981943 -0.991379 -0.998828
# ...

# %%
y_train = pd.read_csv('dataset/train/y_train.txt',header=None, delim_whitespace=True)
y_train
# Out:
#       0
# 0     5
# 1     5
# 2     5
# 3     5
# 4     5
# 5     5
# 6     5
# 7     5
# 8     5
# 9     5
# 10    5
# 11    5
# 12    5
# 13    5
# 14    5
# 15    5
# 16    5
# 17    5
# 18    5
# 19    5
# 20    5
# 21    5
# 22    5
# 23    5
# 24    5
# 25    5
# 26    5
# 27    4
# 28    4
# 29    4
# ...  ..
# 7322  2
# 7323  2
# 7324  2
# 7325  2
# 7326  2
# 7327  2
# 7328  2
# 7329  2
# 7330  2
# 7331  2
# 7332  2
# 7333  2
# 7334  2
# 7335  2
# 7336  2
# 7337  2
# 7338  2
# 7339  2
# 7340  2
# 7341  2
# 7342  2
# 7343  2
# 7344  2
# 7345  2
# 7346  2
# 7347  2
# 7348  2
# 7349  2
# 7350  2
# 7351  2
#
# [7352 rows x 1 columns]

# %%
y_test = pd.read_csv('dataset/test/y_test.txt',header=None, delim_whitespace=True)
y_test
# Out:
#       0
# 0     5
# 1     5
# 2     5
# 3     5
# 4     5
# 5     5
# 6     5
# 7     5
# 8     5
# 9     5
# 10    5
# 11    5
# 12    5
# 13    5
# 14    5
# 15    5
# 16    5
# 17    5
# 18    5
# 19    5
# 20    5
# 21    5
# 22    5
# 23    5
# 24    5
# 25    5
# 26    5
# 27    5
# 28    5
# 29    5
# ...  ..
# 2917  2
# 2918  2
# 2919  2
# 2920  2
# 2921  2
# 2922  2
# 2923  2
# 2924  2
# 2925  2
# 2926  2
# 2927  2
# 2928  3
# 2929  3
# 2930  3
# 2931  3
# 2932  3
# 2933  3
# 2934  3
# 2935  3
# 2936  3
# 2937  2
# 2938  2
# 2939  2
# 2940  2
# 2941  2
# 2942  2
# 2943  2
# 2944  2
# 2945  2
# 2946  2
#
# [2947 rows x 1 columns]

# %%
nb = linear_model.SGDClassifier(max_iter=10000, tol=1e-5)
nb.fit(X_train, y_train.values.ravel())   
y_predict = nb.predict(X_test)  
print("Precisão Stochastic Gradient Descent: {:.2f}".format(nb.score(X_test, y_test)))
# Out:
# Precisão Stochastic Gradient Descent: 0.96

# %%
cm = confusion_matrix(y_test.values, y_predict)
cm
# Out:
# array([[491,   1,   4,   0,   0,   0],
#        [ 15, 454,   2,   0,   0,   0],
#        [  2,   9, 409,   0,   0,   0],
#        [  0,   3,   0, 447,  41,   0],
#        [  0,   0,   0,  28, 504,   0],
#        [  0,   0,   0,   0,   0, 537]])

# %%
from mlxtend.plotting import plot_confusion_matrix
fig, ax = plot_confusion_matrix(conf_mat=cm,
                                colorbar=True,
                                show_absolute=False,
                                show_normed=True)
plt.show()
